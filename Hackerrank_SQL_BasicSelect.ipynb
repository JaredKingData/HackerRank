# %%
# %load_ext sql

# %% [markdown]
# **Note: This code will not run in this notebook because Hackerrank does not give you access to their databases except within the context of using them to solve problems on their website. I am using this notebook to document notes on my solutions to those problems.**

# %% [markdown]
# # Basic Select
# ## Revising the Select Query I
# Query all columns for all American cities in the CITY table with populations larger than 100000. The CountryCode for America is USA.
#
# The CITY table is described as follows:

# %%
from IPython.display import Image
Image(filename='C:/Users/jacos/Desktop/Hackerrank_Images/RSQ_I.jpg')

# %%
SELECT *
FROM CITY
WHERE CountryCode = 'USA'        
    AND Population > 100000;
# Out:
#   File "C:\Users\jacos\AppData\Local\Temp\ipykernel_13572\3636621003.py", line 1
#     SELECT *
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Revising the Select Query II
# Query the NAME field for all American cities in the CITY table with populations larger than 120000. The CountryCode for America is USA.

# %%
SELECT NAME
FROM CITY
WHERE CountryCode = 'USA'
    AND Population > 120000;

# %% [markdown]
# ## Select All
# Query all columns (attributes) for every row in the CITY table.

# %%
SELECT *
FROM CITY;

# %% [markdown]
# ## Select by ID
# Query all columns for a city in CITY with the ID 1661.

# %%
SELECT *
FROM CITY
WHERE ID = 1661;

# %% [markdown]
# ## Japenese Cities' Attributes
# Query all attributes of every Japanese city in the CITY table. The COUNTRYCODE for Japan is JPN.

# %%
SELECT *
FROM CITY
WHERE CountryCode = 'JPN';

# %% [markdown]
# ## Japanese Cities' Names
# Query the names of all the Japanese cities in the CITY table. The COUNTRYCODE for Japan is JPN.

# %%
SELECT Name
FROM CITY
WHERE CountryCode = 'JPN';

# %% [markdown]
# ## Weather Observation Station 1
# Query a list of CITY and STATE from the STATION table.
# The STATION table is described as follows:

# %%
from IPython.display import Image
Image(filename='C:/Users/jacos/Desktop/Hackerrank_Images/Station.jpg')

# %%
SELECT CITY, 
    STATE
FROM STATION;

# %% [markdown]
# ## Weather Observation Station 3
# Query a list of CITY names from STATION for cities that have an even ID number. Print the results in any order, but exclude duplicates from the answer.

# %%
SELECT DISTINCT CITY
FROM STATION
WHERE MOD(ID, 2) = 0;

# %% [markdown]
# ## Weather Observation Station 4
# Find the difference between the total number of CITY entries in the table and the number of distinct CITY entries in the table.

# %%
SELECT COUNT(*) - COUNT(DISTINCT CITY) as difference
FROM STATION;

# %% [markdown]
# ## Weather Observation Station 5
# Query the two cities in STATION with the shortest and longest CITY names, as well as their respective lengths (i.e.: number of characters in the name). If there is more than one smallest or largest city, choose the one that comes first when ordered alphabetically.

# %%
(SELECT CITY, LENGTH(CITY) AS NAME_LENGTH
FROM STATION
ORDER BY NAME_LENGTH, CITY
LIMIT 1)
UNION
(SELECT CITY, LENGTH(CITY) AS NAME_LENGTH
FROM STATION
ORDER BY NAME_LENGTH DESC, CITY
LIMIT 1);

# %% [markdown]
# ## Weather Observation Station 6
# Query the list of CITY names starting with vowels (i.e., a, e, i, o, or u) from STATION. Your result cannot contain duplicates.

# %%
SELECT DISTINCT CITY
FROM STATION
WHERE CITY LIKE 'A%' 
    OR CITY LIKE 'E%' 
    OR CITY LIKE 'I%' 
    OR CITY LIKE 'O%' 
    OR CITY LIKE 'U%';
# Out:
#   File "C:\Users\jacos\AppData\Local\Temp\ipykernel_13572\261312234.py", line 1
#     SELECT CITY
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Weather Observation Station 7
# Query the list of CITY names ending with vowels (a, e, i, o, u) from STATION. Your result cannot contain duplicates.

# %%
SELECT DISTINCT CITY
FROM STATION
WHERE CITY LIKE '%A'
    OR CITY LIKE '%E'
    OR CITY LIKE '%I'
    OR CITY LIKE '%O'
    OR CITY LIKE '%U';

# %% [markdown]
# ## Weather Observation Station 8
# Query the list of CITY names from STATION which have vowels (i.e., a, e, i, o, and u) as both their first and last characters. Your result cannot contain duplicates.

# %%
SELECT DISTINCT CITY 
FROM STATION 
WHERE LEFT(CITY, 1) IN ('a', 'e', 'i', 'o', 'u') 
    AND RIGHT(CITY, 1) IN ('a', 'e', 'i', 'o', 'u');

# %% [markdown]
# ## Weather Observation Station 9
# Query the list of CITY names from STATION that do not start with vowels. Your result cannot contain duplicates.

# %%
SELECT DISTINCT CITY 
FROM STATION 
WHERE CITY NOT REGEXP '^[aeiouAEIOU]';

# %% [markdown]
# ## Weather Observation Station 10
# Query the list of CITY names from STATION that do not end with vowels. Your result cannot contain duplicates.

# %%
SELECT DISTINCT CITY 
FROM STATION
WHERE CITY NOT REGEXP '[aeiou]$';

# %% [markdown]
# ## Weather Observation Station 11
# Query the list of CITY names from STATION that either do not start with vowels or do not end with vowels. Your result cannot contain duplicates.

# %%
SELECT DISTINCT CITY
FROM STATION
WHERE (NOT(CITY  Like 'A%' OR CITY LIKE 'E%' OR CITY LIKE 'O%' OR CITY LIKE 'I%' OR CITY LIKE 'U%'))
        OR 
      (NOT (CITY LIKE '%a' OR CITY  LIKE '%e' OR CITY LIKE '%i' OR CITY LIKE '%o' OR CITY LIKE '%u'))
ORDER BY CITY;

# %% [markdown]
# ## Weather Observation Station 12
# Query the list of CITY names from STATION that do not start with vowels and do not end with vowels. Your result cannot contain duplicates.

# %%
SELECT DISTINCT CITY
FROM STATION
WHERE LOWER(SUBSTR(CITY, 1, 1)) NOT IN ('a', 'e', 'i', 'o', 'u') -- Exclude names starting with vowels
  AND LOWER(SUBSTR(CITY, LENGTH(CITY), 1)) NOT IN ('a', 'e', 'i', 'o', 'u') -- Exclude names ending with vowels
ORDER BY CITY;

# %% [markdown]
# ## Higher Than 75 Marks
# Query the Name of any student in STUDENTS who scored higher than 75 Marks. Order your output by the last three characters of each name. If two or more students both have names ending in the same last three characters (i.e.: Bobby, Robby, etc.), secondary sort them by ascending ID.
#
# The STUDENTS table is described as follows:

# %%
from IPython.display import Image
Image(filename='C:/Users/jacos/Desktop/Hackerrank_Images/75marks.png')

# %%
SELECT t.name
FROM students t
WHERE t.marks > 75 
ORDER BY RIGHT(t.name, 3), t.id ASC;

# %% [markdown]
# ## Employee Names
# Write a query that prints a list of employee names (i.e.: the name attribute) from the Employee table in alphabetical order.

# %%
from IPython.display import Image
Image(filename='C:/Users/jacos/Desktop/Hackerrank_Images/Employee.png')

# %%
SELECT name
FROM Employee
ORDER BY name ASC;

# %% [markdown]
# ## Employee Salaries
# Write a query that prints a list of employee names (i.e.: the name attribute) for employees in Employee having a salary greater than 2000 per month who have been employees for less than  months. Sort your result by ascending employee_id.

# %%
SELECT name
FROM Employee
WHERE salary > 2000 AND months < 10
ORDER BY employee_id ASC;
# Out:
#   File "C:\Users\jacos\AppData\Local\Temp\ipykernel_13572\1154497324.py", line 1
#     SELECT name
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##
